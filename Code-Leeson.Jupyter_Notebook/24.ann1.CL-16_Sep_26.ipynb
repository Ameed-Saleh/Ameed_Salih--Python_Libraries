# %% [markdown]
# ![image.png](attachment:06e5fb9d-47ab-4f7c-b12a-36d991912135.png)

# %% [markdown]
# ![image.png](attachment:5bcb7a8c-e777-42c3-b92f-fe70243b2bff.png)

# %% [markdown]
# ![image.png](attachment:0998ab7c-5317-47f5-ac9c-7230fdf46195.png)

# %% [markdown]
# ![image.png](attachment:d93e72c5-f23c-48c1-8600-bea2620a86de.png)

# %% [markdown]
# ![image.png](attachment:205ad070-8187-4618-8ba8-3376b141df5a.png)

# %% [markdown]
# ![image.png](attachment:0bae8a56-5b13-4c69-b833-d35aafa8a831.png)

# %% [markdown]
# ![image.png](attachment:fb4367b9-704b-47f9-83b5-9a46e5e784f5.png)

# %% [markdown]
# ![image.png](attachment:b0d77886-1975-414f-b1ff-5931d9d6b5c0.png)
# ![image.png](attachment:6bcf3f84-93ad-416a-bfad-832971df954c.png)
# ![image.png](attachment:01be044a-a51b-4838-9f3f-e5ad3bdecabf.png)

# %% [markdown]
# ![image.png](attachment:0cca4c9d-03e2-423a-8dd5-4a59763713b0.png)

# %% [markdown]
# ![image.png](attachment:91353aa2-0db7-4065-9f30-638b74345b0e.png)
# ![image.png](attachment:9be0df74-51a0-4458-88ad-75742a09dba0.png)
# ![image.png](attachment:42335d38-4046-468b-a7bc-b19033cf5c8c.png)

# %% [markdown]
# ![image.png](attachment:429de0e1-2f50-4f34-a589-6d0b266b55af.png)

# %% [markdown]
# ![image.png](attachment:bd279e28-49af-4ead-b5f7-822a06d41c3b.png)

# %% [markdown]
# ![image.png](attachment:550efaf0-016c-4f4b-b7ff-8f65f920f60f.png)

# %%
import numpy as np 
import pandas as pd
print(pd.__version__)
# Out:
# 2.3.3

# %%
pd.Series([10, 100, 15, 35]) # index
np.array([10, 100, 15, 35]) # no index
print(type(pd.Series([10, 100, 15, 35])))
# Out:
# <class 'pandas.core.series.Series'>

# %%
s1 = pd.Series([1,2,3,])
print(s1)
s1[0]  # key = 0
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64
# np.int64(1)

# %%
countries = {
    'USA':    1776,
    'CANADA': 1867,
    'MEXICO': 1821
}
s = pd.Series(countries)
print(s)
# Out:
# USA       1776
# CANADA    1867
# MEXICO    1821
# dtype: int64

# %%
years = [1776, 1867, 1821]
label_index = ['USA', 'CANADA', 'MEXICO']
pd.Series(years, label_index)
pd.Series(data=years, index=label_index)  
countries = pd.Series(data=years, index=label_index)  # better
print(countries)
# create business card index f-name, l-name, city, country
# 1
# create series that looks like:
# f-name  Danny
# l-name  Shovevani
# city    Rehovot
# country Israel
# 2
# input the values from the user
# create the card from the input
print()
card_values = ['Danny', 'Shovevani', 'Rehovot', 'Israel']
card_index = ['f-name ', 'l-name', 'city', 'country'] 
business_card = pd.Series(data=card_values, index=card_index)  # better
print(business_card)
f_name = input("What's your first name? ")
l_name = input("What's your last name? ")
city = input("What city do you live in? ")
country = input("What country do you live in? ")
# Out:
# USA       1776
# CANADA    1867
# MEXICO    1821
# dtype: int64
#
# f-name         Danny
# l-name     Shovevani
# city         Rehovot
# country       Israel
# dtype: object
# What's your first name?  Ameed
# What's your last name?  Saleh
# What city do you live in?  Maghar
# What country do you live in?  Israel

# %%
years = [1776, 1867, 1821]
label_index = ['USA', 'CANADA', 'MEXICO']
countries = pd.Series(data=years, index=label_index) 

print(countries)
print(countries.keys())
print(countries.keys()[0])
print(list(countries.keys()))
# countries[0]   bad -- because the index is label and not number
# countries[KEY] == countries.loc[KEY]
# Out:
# USA       1776
# CANADA    1867
# MEXICO    1821
# dtype: int64
# Index(['USA', 'CANADA', 'MEXICO'], dtype='object')
# USA
# ['USA', 'CANADA', 'MEXICO']

# %%
first  = pd.Series({'Japan': 100, 'China': 450, 'USA': 250})
second = pd.Series({'Brazil': 70, 'China': 350, 'USA': 200})

result = first + second
print(result)
# Out:
# Brazil      NaN
# China     800.0
# Japan       NaN
# USA       450.0
# dtype: float64

# %%
first  = pd.Series({'Japan': 100, 'China': 450, 'USA': 250})
second = pd.Series({'Brazil': 70, 'China': 350, 'USA': 200})
result = first.add(second, fill_value=0)
print(result)

print()

hello = pd.Series({'Ameed':56, 'Waleed':52, 'Golan':81})
hi = pd.Series({'Ameed':94, 'Waleed':68, 'Golan':59})
result = hello.add(hi, fill_value=0)
print(result)
print()
print(result.astype(float))
# Out:
# Brazil     70.0
# China     800.0
# Japan     100.0
# USA       450.0
# dtype: float64
#
# Ameed     150
# Waleed    120
# Golan     140
# dtype: int64
#
# Ameed     150.0
# Waleed    120.0
# Golan     140.0
# dtype: float64

# %%
first  = pd.Series({'Japan': 100.2, 'China': 450, 'USA': 250})
print(first.dtype)  # float64

first  = pd.Series({'Japan': 100, 'China': 450, 'USA': 250})
print(first.dtype)  # int64

print(first)
# Out:
# float64
# int64
# Japan    100
# China    450
# USA      250
# dtype: int64

# %%
first  = pd.Series({'Japan': 100.99, 'China': 450, 'USA': 250})
print(first.dtype) 
print(first.astype(int))
# Out:
# float64
# Japan    100
# China    450
# USA      250
# dtype: int64

# %%
# Inventory for Tel Aviv Branch
tel_aviv = pd.Series({
    'MacBook Pro': 5, 
    'LG Screen 27': 1, 
    'Logitech Mouse': 12
})

# Inventory for Haifa Branch
haifa = pd.Series({
    'MacBook Pro': 3, 
    'iPad Air': 7, 
    'Logitech Mouse': 8
})

# %%
# ADD another store
# 1 add another store with random items from store 1 , and store 2 and random stock
# 2 input product name from user 
# 3 print the TOTAL items in stock from all 3 stores for the product the user input --> if not exist return 0
# hint: use add + fill_value and is in 
# example:
# first  = pd.Series({'Japan': 100, 'China': 450, 'USA': 250})
# second = pd.Series({'Brazil': 70, 'China': 350, 'USA': 200})
# result = first.add(second, fill_value=0)

modiin = pd.Series ({
    'MacBook Pro': 1, 
    'LG Screen 27': 2,
    'iPad Air': 4
})

total_stock = tel_aviv.add(haifa, fill_value=0).add(modiin, fill_value=0)
print(total_stock)
product = input('product?')
print(total_stock.get(product, f'Error {product} not exist in inventory'))

print()

if product.strip() not in total_stock:  # if product.strip() not in total_stock.keys():
    print(0)
else:
    print(total_stock[product.strip()])
# Out:
# LG Screen 27       3.0
# Logitech Mouse    20.0
# MacBook Pro        9.0
# iPad Air          11.0
# dtype: float64
# product? Iphone
# Error Iphone not exist in inventory
#
# 0

# %%
tips_df = pd.read_csv('tips.csv')
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
type(tips_df)
# Out:
# pandas.core.frame.DataFrame

# %%
tips_df = pd.read_csv('tips.csv')
tips_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
tips_df = pd.read_csv('tips.csv')
print(tips_df.columns)
print(tips_df.index)
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')
# RangeIndex(start=0, stop=244, step=1)

# %%
tips_df = pd.read_csv('tips.csv')
print(len(tips_df))
tips_df.head()
tips_df.tail()
# Out:
# 244
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID
# 239    Michael Avila  5296068606052842    Sat2657
# 240   Monica Sanders  3506806155565404    Sat1766
# 241       Keith Wong  6011891618747196    Sat3880
# 242     Dennis Dixon     4375220550950      Sat17
# 243  Michelle Hardin  3511451626698139    Thur672

# %%
tips_df = pd.read_csv('tips.csv')
tips_df.describe()
#tips_df.describe().transpose()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
tips_df = pd.read_csv('tips.csv')
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
tips_df = pd.read_csv('tips.csv')
tips_df['tip']
tips_df[ ['tip', 'day'] ]
# Out:
#       tip   day
# 0    1.01   Sun
# 1    1.66   Sun
# 2    3.50   Sun
# 3    3.31   Sun
# 4    3.61   Sun
# ..    ...   ...
# 239  5.92   Sat
# 240  2.00   Sat
# 241  2.00   Sat
# 242  1.75   Sat
# 243  3.00  Thur
#
# [244 rows x 2 columns]

# %%
tips_df = pd.read_csv('tips.csv')
tips_df['new_column'] = tips_df['tip'] + tips_df['total_bill']
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID  new_column
# ...

# %%
tips_df = pd.read_csv('tips.csv')
tips_df.drop(0, inplace=True)
tips_df.drop('tip', axis=1, inplace=True) # remove column 'tip'
tips_df
# Out:
#      total_bill     sex smoker   day    time  size  price_per_person  \
# 1         10.34    Male     No   Sun  Dinner     3              3.45
# 2         21.01    Male     No   Sun  Dinner     3              7.00
# 3         23.68    Male     No   Sun  Dinner     2             11.84
# 4         24.59  Female     No   Sun  Dinner     4              6.15
# 5         25.29    Male     No   Sun  Dinner     4              6.32
# ..          ...     ...    ...   ...     ...   ...               ...
# 239       29.03    Male     No   Sat  Dinner     3              9.68
# 240       27.18  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82    Male     No   Sat  Dinner     2              8.91
# 243       18.78  Female     No  Thur  Dinner     2              9.39
#
#            Payer Name         CC Number Payment ID
# 1      Douglas Tucker  4478071379779230    Sun4608
# ...

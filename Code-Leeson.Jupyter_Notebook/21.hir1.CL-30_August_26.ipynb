# %% [markdown]
# ![image.png](attachment:898bf789-ec2e-4414-942a-0d8cffb17564.png)

# %% [markdown]
# ![image.png](attachment:797d3bce-7af7-408a-906a-89793906b331.png)

# %% [markdown]
# ![image.png](attachment:f936aa3c-844d-428e-8ac9-d0890832f7df.png)

# %% [markdown]
# ![image.png](attachment:d6363222-c539-4d4e-a6fa-9c3a74efe49b.png)

# %% [markdown]
# ![image.png](attachment:f2a3d8a6-a390-4b9a-aabd-7ee9553a947b.png)

# %% [markdown]
# ![image.png](attachment:e00648f5-39a1-4758-a429-ca8f1d615742.png)

# %% [markdown]
# ![image.png](attachment:b4c69f43-43e5-41cb-9669-2dc5ce2aace7.png)

# %% [markdown]
# ![image.png](attachment:6c549fdf-e6fd-4aa8-b3e0-e21b50e76e08.png)
# ![image.png](attachment:a14ef112-4fe9-4b87-8d88-6e3c010cf09e.png)

# %% [markdown]
# ![image.png](attachment:73d79b2f-2710-4d98-8a5b-a9df8013026f.png)

# %% [markdown]
# ![image.png](attachment:f4b82798-f0bd-4392-98c3-c3e780bb8b81.png)

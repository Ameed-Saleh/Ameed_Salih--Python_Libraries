# %% [markdown]
# ![image.png](attachment:3b7221b8-949c-484f-93ea-87a961eb5cb6.png)

# %% [markdown]
# ![image.png](attachment:f9b0d4b9-9fe2-4f26-ba95-21996fd94d2e.png)

# %% [markdown]
# ![image.png](attachment:3a41c21e-e91d-4934-80fc-ca42b80dc933.png)

# %% [markdown]
# ![image.png](attachment:1b7224a1-df73-4177-ab73-bf55a3f20ee1.png)
# ![image.png](attachment:c5ca5afe-cc69-490e-b3fc-403233228dc3.png)

# %% [markdown]
# ![image.png](attachment:d71d0f08-316d-4c26-9b27-44b8add57293.png)

# %% [markdown]
# ![image.png](attachment:628eb736-98ba-4995-b30d-456336b236b9.png)
# ![image.png](attachment:cb785270-2384-4ca4-b6ac-614703cdea14.png)

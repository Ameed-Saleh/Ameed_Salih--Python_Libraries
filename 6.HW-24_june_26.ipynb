# %%
import pandas as pd
import numpy  as np
from IPython.display import display

# %%
# Exercise
# Use Churn_Modelling.csv
# Create a notebook, solve any 3 questions from Task 1 to Task 10, and solve Task 11

# %%
# Task 1
# Setup & data: Load the file with df = pd.read_csv('Churn_Modelling.csv').
# Display the first 7 rows, then print df.shape and df.columns
df = pd.read_csv('Churn_Modelling.csv')
display(df.head(7))
print(f'\n df.shape -> {df.shape}\n')
print(f'df.columns -> {df.columns}')
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
# 5          6    15574012       Chu          645     Spain    Male   44
# 6          7    15592531  Bartlett          822    France    Male   50
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
# ...

# %%
# Task 2
# Sorting: Sort customers by CreditScore from lowest to highest and show the first 7 rows
df = pd.read_csv('Churn_Modelling.csv')
display(df.sort_values(by=['CreditScore'], ascending=True).head(7))
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 8762       8763    15765173        Lin          350    France  Female   60
# 8723       8724    15803202  Onyekachi          350    France    Male   51
# 1838       1839    15758813   Campbell          350   Germany    Male   39
# 9624       9625    15668309     Maslow          350    France  Female   40
# 1631       1632    15685372   Azubuike          350     Spain    Male   54
# 2473       2474    15679249       Chou          351   Germany  Female   57
# 1962       1963    15692416  Aikenhead          358     Spain  Female   52
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 8762       3       0.00              1          0               0
# 8723      10       0.00              1          1               1
# 1838       0  109733.20              2          0               0
# 9624       0  111098.85              1          1               1
# ...

# %%
# Task 3
# Multi-column sorting: Sort by Geography ascending and Balance descending.
# Show the first 12 rows and explain what the two sort directions mean
df = pd.read_csv('Churn_Modelling.csv')
display(df.sort_values(by=['Geography', 'Balance'], ascending=[True, False]).head(12))
# Geography ascending -> lowest to highest this means sorting alphabetically (A to Z).
# Balance descending -> highest to lowest this means sorting numerically decreasing.
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 3280       3281    15715622     To Rot          583    France  Female   57
# 1533       1534    15769818      Moore          850    France  Female   37
# 2709       2710    15780212        Mao          592    France    Male   37
# 8702       8703    15690589    Udinesi          541    France    Male   37
# 520         521    15671256  Macartney          850    France  Female   35
# 7353       7354    15736420  Macdonald          596    France    Male   21
# 5871       5872    15709920      Burke          479    France  Female   33
# 8982       8983    15627971     Coates          504    France  Female   32
# 6913       6914    15784180         Ku          564    France  Female   36
# 4436       4437    15664498  Golovanov          508    France    Male   26
# 9920       9921    15673020      Smith          678    France  Female   49
# ...

# %%
# Task 4
# Counts: Use value_counts() to count customers by Geography.
# Then count each Geography + Gender combination
df = pd.read_csv('Churn_Modelling.csv')
display(df['Geography'].value_counts())
print()
display(df[['Geography', 'Gender']].value_counts())
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64
# Geography  Gender
# France     Male      2753
#            Female    2261
# Spain      Male      1388
# Germany    Male      1316
#            Female    1193
# Spain      Female    1089
# Name: count, dtype: int64

# %%
# Task 5
# Unique values: Show the unique values in Geography, Gender, NumOfProducts, and Exited.
# Then use nunique() to count how many different values each of these columns has
df = pd.read_csv('Churn_Modelling.csv')
columns = ['Geography', 'Gender', 'NumOfProducts', 'Exited']

for col in columns:
    display(f'{col} unique values: {df[col].unique()}')
print()
for col in columns:
    display(f'{col} nunique values: {df[col].nunique()}')
# Out:
# "Geography unique values: ['France' 'Spain' 'Germany']"
# "Gender unique values: ['Female' 'Male']"
# 'NumOfProducts unique values: [1 3 2 4]'
# 'Exited unique values: [1 0]'
# 'Geography nunique values: 3'
# 'Gender nunique values: 2'
# 'NumOfProducts nunique values: 4'
# 'Exited nunique values: 2'

# %%
# Task 6
# Replace & map: Create a copy of the DataFrame.
# In the copy, replace Female with F and Male with M using .replace().
# Then solve the same change with .map()
df = pd.read_csv('Churn_Modelling.csv')
copy_df = df.copy()
copy_df['Gender'] = copy_df['Gender'].replace(['Female', 'Male'], ['F', 'M'])
display(copy_df['Gender'].to_frame())
print()
gender_map = { 'Female': 'F', 'Male': 'M' }
copy_df['Gender'] = copy_df['Gender'].map(gender_map)
display(copy_df['Gender'].to_frame())
# Out:
#      Gender
# 0         F
# 1         F
# 2         F
# 3         F
# 4         F
# ...     ...
# 9995      M
# 9996      M
# 9997      F
# 9998      M
# 9999      F
#
# [10000 rows x 1 columns]
#      Gender
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ...     ...
# 9995    NaN
# 9996    NaN
# 9997    NaN
# 9998    NaN
# 9999    NaN
#
# [10000 rows x 1 columns]

# %%
# Task 7
# Top & lowest values: Find the 6 customers with the highest Balance using nlargest.
# Then find the 4 customers with the lowest CreditScore using nsmallest
df = pd.read_csv('Churn_Modelling.csv') # shows the sex highest Balace.
display(df.nlargest(6, 'Balance'))
print()
display(df.nsmallest(4, 'CreditScore')) # shows the four lowest CreditScore.
# Out:
#       RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 2092       2093    15757408        Lo          655     Spain    Male   38
# 3280       3281    15715622    To Rot          583    France  Female   57
# 8733       8734    15714241    Haddon          749     Spain    Male   42
# 3588       3589    15571958  McIntosh          489     Spain    Male   40
# 6717       6718    15586674      Shaw          663     Spain  Female   58
# 1067       1068    15599131     Dilke          650   Germany    Male   26
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 2092       3  250898.09              3          0               1
# 3280       3  238387.56              1          0               1
# 8733       9  222267.63              1          0               0
# 3588       3  221532.80              1          1               0
# 6717       5  216109.88              1          0               1
# ...

# %%
# Task 8
# sample(): Show 9 random customers using sample(9).
# Then show a 3% random sample using sample(frac=0.03)
df = pd.read_csv('Churn_Modelling.csv')
display(df.sample(9))
print()
display(df.sample(frac=0.03))
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 7807       7808    15568904     Kruglova          608   Germany    Male   34
# 5572       5573    15613140       Mellor          565    France    Male   34
# 1842       1843    15747222      Bentley          745     Spain  Female   35
# 5088       5089    15734610         Onio          543    France    Male   42
# 9992       9993    15657105  Chukwualuka          726     Spain    Male   36
# 8158       8159    15744127     Kosovich          641    France  Female   37
# 8261       8262    15570855      Leonard          670    France    Male   38
# 3291       3292    15635893        T'ien          693    France  Female   28
# 3864       3865    15808960      Alleyne          620   Germany    Male   40
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 7807       3  106288.54              1          1               1
# ...

# %%
# Task 9
# Duplicates: Check whether the dataset has duplicated CustomerId values.
# Then use sorting plus drop_duplicates('Geography') to keep one customer per country with the highest Balance

df = pd.read_csv('Churn_Modelling.csv')
print(f'Are there duplicated CustomerIds? {df['CustomerId'].duplicated().any()}')
display(df['CustomerId'].duplicated().to_frame())
display(df.sort_values(by= ['Balance'], ascending=[False]).drop_duplicates(subset=['Geography'], keep='first'))
# Out:
# Are there duplicated CustomerIds? False
#       CustomerId
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# ...          ...
# 9995       False
# 9996       False
# 9997       False
# 9998       False
# 9999       False
#
# [10000 rows x 1 columns]
#       RowNumber  CustomerId Surname  CreditScore Geography  Gender  Age  \
# 2092       2093    15757408      Lo          655     Spain    Male   38
# 3280       3281    15715622  To Rot          583    France  Female   57
# 1067       1068    15599131   Dilke          650   Germany    Male   26
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 2092       3  250898.09              3          0               1
# 3280       3  238387.56              1          0               1
# 1067       4  214346.96              2          1               0
#
#       EstimatedSalary  Exited
# 2092         81054.00       1
# 3280        147964.99       1
# ...

# %%
# Task 10
# Largest values plus unique values: Find the 12 customers with the highest EstimatedSalary.
# From those rows, print the unique Geography values

df = pd.read_csv('Churn_Modelling.csv')
display(df.nlargest(12, 'EstimatedSalary'))
print()
display(df.nlargest(12, 'EstimatedSalary')['Geography'].unique())
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 6646       6647    15662021   Lucciano          685     Spain  Female   42
# 3580       3581    15634359       Dyer          639   Germany  Female   41
# 4417       4418    15697270     Gannon          608     Spain    Male   27
# 9096       9097    15762331       Moss          569    France    Male   37
# 8926       8927    15709136      Adams          620    France    Male   28
# 5958       5959    15741719     DeRose          540    France  Female   40
# 1378       1379    15682834  Johnstone          715     Spain  Female   35
# 6402       6403    15804211  Oluchukwu          719    France    Male   36
# 8088       8089    15815656    Hopkins          541   Germany  Female   39
# 6125       6126    15687913        Mai          501   Germany  Female   34
# 3830       3831    15720713   Chibueze          850    France  Female   29
# ...

# %%
# Task 11
# Missing data: Use the DataFrame below and implement the requested cleaning operations

df_missing = pd.DataFrame({
    'A': [None, 2, 3, None, 5, None],
    'B': [10, None, None, 40, 50, None],
    'C': [100, None, 300, 400, None, None]
})
display(df_missing)
print('Task 11 -> Q1')
# Eliminate any row in the DataFrame that contains at least one NaN value
display(df_missing.dropna())
print('\nTask 11 -> Q2')
# Modify the previous task and eliminate only rows that have NaN values across all columns
display(df_missing.dropna(thresh=1))
print('\nTask 11 -> Q3')
# Eliminate rows that have at least one NaN in columns A and C only
display(df_missing.dropna(subset=['A', 'C'], thresh=1))
display(df_missing.dropna(subset=['A', 'C']))
print('\nTask 11 -> Q4')
# Replace all NaN values with a specified value of your choice
df_filled = df_missing.fillna(1)
display(df_filled)
print('\nTask 11 -> Q5')
# Replace all NaN values in column B with the mean of the non-NaN values in that column
df_missing['B'] = df_missing['B'].fillna(df_missing['B'].mean())
display(df_missing)
# Out:
#      A     B      C
# 0  NaN  10.0  100.0
# 1  2.0   NaN    NaN
# 2  3.0   NaN  300.0
# 3  NaN  40.0  400.0
# 4  5.0  50.0    NaN
# 5  NaN   NaN    NaN
# Task 11 -> Q1
# Empty DataFrame
# Columns: [A, B, C]
# Index: []
# Task 11 -> Q2
#      A     B      C
# 0  NaN  10.0  100.0
# 1  2.0   NaN    NaN
# 2  3.0   NaN  300.0
# 3  NaN  40.0  400.0
# 4  5.0  50.0    NaN
# Task 11 -> Q3
#      A     B      C
# 0  NaN  10.0  100.0
# 1  2.0   NaN    NaN
# 2  3.0   NaN  300.0
# 3  NaN  40.0  400.0
# 4  5.0  50.0    NaN
#      A   B      C
# 2  3.0 NaN  300.0
# Task 11 -> Q4
#      A     B      C
# 0  1.0  10.0  100.0
# 1  2.0   1.0    1.0
# 2  3.0   1.0  300.0
# 3  1.0  40.0  400.0
# 4  5.0  50.0    1.0
# 5  1.0   1.0    1.0
# Task 11 -> Q5
#      A          B      C
# 0  NaN  10.000000  100.0
# 1  2.0  33.333333    NaN
# 2  3.0  33.333333  300.0
# 3  NaN  40.000000  400.0
# 4  5.0  50.000000    NaN
# 5  NaN  33.333333    NaN

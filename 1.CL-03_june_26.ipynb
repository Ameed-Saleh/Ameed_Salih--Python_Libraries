# %%
print('Ameed Salih')

# %%
# 1
# print numbers 1 to 5 in a loop
# 2
# define function mul(x,y) -> print x*y
# in differnet cell input x and input y
# call the mul function and print its output

# %%
for i in range (1, 5 +1):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
def mul(x,y):
    print(f"x*y = {x*y}")

# %%
x: int = input("enter a number for x:")

# %%
y: int = input("enter a number for y:")

# %%
mul(10,8)

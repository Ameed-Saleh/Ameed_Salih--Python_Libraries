# %%
import numpy as np

# %%
# Topic 07 of 09
# Comparison & Statistics

# %%
# Q1
# Given the two matrices below — what shape and values do you get with axis=0 vs axis=1?
# m1 = np.array([[1, 2], [3, 4]])
# m2 = np.array([[5, 6], [7, 8]])
# np.concatenate((m1, m2), axis=0)  # shape: (?, ?)
# np.concatenate((m1, m2), axis=1)  # shape: (?, ?)

m1 = np.array([[1, 2], [3, 4]])
m2 = np.array([[5, 6], [7, 8]])
print(f'when axis=0 the shape is return-> {np.concatenate((m1, m2), axis=0).shape}') # shape: (?, ?)
print(f'when axis=1 the shape is return-> {np.concatenate((m1, m2), axis=1).shape}')   # shape: (?, ?)
# Out:
# when axis=0 the shape is return-> (4, 2)
# when axis=1 the shape is return-> (2, 4)

# %%
# Q2
# Given a = np.array([1,2,3]) and b = np.array([1,5,3]) — what does a == b return?
# array([?, ?, ?])

a = np.array([1,2,3]) 
b = np.array([1,5,3])
print(f'a==b return-> {a==b}')
# Out:
# a==b return-> [ True False  True]

# %%
# Q3
# Given a = np.array([2,4,4,4,5,5,7,9]) — what does np.var(a) return? How does it relate to std?
# var = std²
# ?.?

a = np.array([2,4,4,4,5,5,7,9])
print(f'np.var(a) return-> {np.var(a)}')
print(f'np.std(a)**2) return-> {np.std(a)**2} - because variance is std squared')
# Out:
# np.var(a) return-> 4.0
# np.std(a)**2) return-> 4.0 - because variance is std squared

# %%
# Q4
# Given a = np.array([[1,2],[3,4]]) — what does a.sum(axis=0) return?
# axis=0 = sum each column
# array([?, ?])

a = np.array([[1,2],[3,4]])
print(f'a.sum(axis=0) return-> {a.sum(axis=0)}')
# Out:
# a.sum(axis=0) return-> [4 6]

# %%
# Q5
# Given a = np.array([1, 5, 3, 8, 2]) — what does a > 3 return?
# array([?, ?, ?, ?, ?])

a = np.array([1, 5, 3, 8, 2])
print(f'a > 3 return-> {a > 3}')
# Out:
# a > 3 return-> [False  True False  True False]

# %%
# Q6
# Given a = np.array([1,2,3]) and b = np.array([1,2,3]) — what does np.array_equal(a, b) return?

a = np.array([1,2,3]) 
b = np.array([1,2,3])
print(f'np.array_equal(a, b) return-> {np.array_equal(a, b)}')
# Out:
# np.array_equal(a, b) return-> True

# %%
# Q7
# Given a = np.arange(1, 6) — what does a.mean() return?
# a = [1, 2, 3, 4, 5]
# ?.?

a = np.arange(1, 6)
print(f'a.mean() return-> {a.mean()}')
# Out:
# a.mean() return-> 3.0

# %%
# Q8
# Given x = np.array([1,2,3]) and y = np.array([2,4,6]) — what is the off-diagonal value of np.corrcoef(x, y)?
# perfectly proportional arrays
# r = ?.?

x = np.array([1,2,3]) 
y = np.array([2,4,6])
print(f'np.corrcoef(x, y) return-> {np.corrcoef(x, y)}')
print(f'So, the off-diagonal value is: r = 1.0 -> perfectly correlated')
# Out:
# np.corrcoef(x, y) return-> [[1. 1.]
#  [1. 1.]]
# So, the off-diagonal value is: r = 1.0 -> perfectly correlated

# %%
# Q9
# Given a = np.array([1, 2]) and b = np.array([3, 4]) — what does np.concatenate((a, b)) return? What about np.concatenate((a, b, a))?
# np.concatenate((a, b))
# array([?, ?, ?, ?])
# np.concatenate((a, b, a))
# array([?, ?, ?, ?, ?, ?])

a = np.array([1, 2]) 
b = np.array([3, 4]) 
print(f'np.concatenate((a, b)) return-> {np.concatenate((a, b))}')
print(f'np.concatenate((a, b, a)) return-> {np.concatenate((a, b, a))}')
# Out:
# np.concatenate((a, b)) return-> [1 2 3 4]
# np.concatenate((a, b, a)) return-> [1 2 3 4 1 2]

# %%
# Q10
# Given a = np.array([3, 1, 7, 2, 9, 4]) — what does a.argmin() and a.argmax() return?
# returns the index, not the value
# argmin: ?   argmax: ?

a = np.array([3, 1, 7, 2, 9, 4])
print(f'a.argmin() return-> {a.argmin()}')
print(f'a.argmax() return-> {a.argmax()}')
# Out:
# a.argmin() return-> 1
# a.argmax() return-> 4

# %%
# Q11
# Given a = np.array([1, 3, 2, 5, 4]) — what does np.median(a) return?

a = np.array([1, 3, 2, 5, 4])
print(f'np.median(a) return-> {np.median(a)}')
# Out:
# np.median(a) return-> 3.0

# %%
# Q12
# Given a = np.array([2,4,4,4,5,5,7,9]) — what does np.std(a) return?

a = np.array([2,4,4,4,5,5,7,9])
print(f' np.std(a) return-> { np.std(a)}')
# Out:
#  np.std(a) return-> 2.0

# %%
# Q13
# Given a = np.array([1, 2, 3, 4]) — what does a.cumsum() return?

a = np.array([1, 2, 3, 4])
print(f'a.cumsum() return-> {a.cumsum()}')
# Out:
# a.cumsum() return-> [ 1  3  6 10]

# %%
# Q14
# Given a = np.array([3, 1, 7, 2, 9, 4]) — what does a.min() and a.max() return?

a = np.array([3, 1, 7, 2, 9, 4])
print(f'a.min() return-> {a.min()}')
print(f'a.max() return-> {a.max()}')
# Out:
# a.min() return-> 1
# a.max() return-> 9
